# %% [markdown]
# # Video Game Sales Data Dleaning and Analysis Project

# %% [markdown]
# ## Loading Data

# %%
# importing appropriate libraries for this projct
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
vgsales = pd.read_csv('vgsales.csv') # read the vgsales csv file into a data frame called vgsales
vgsales.head() # print the first 5 rows in vgsales dataframe
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# ## Cleaning Data

# %%
vgsales.info() # look at the data types for each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
vgsales.isnull().sum() # count the number of missing values in each column
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
vgsales_cleaned = vgsales.dropna() # drop rows with missing values 
vgsales_cleaned.isnull().sum() # missing values checked to ensure they have been removed
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
duplicate_rows = vgsales_cleaned[vgsales_cleaned.duplicated()] #look up duplicated rows
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales]
# Index: []

# %%
# create a copy of vg_sales dataframe and assign to vgsales_final
vgsales_final = vgsales_cleaned.copy()

# Convert 'Year' column to numeric, coercing non-numeric values to NaN
vgsales_final['Year'] = pd.to_numeric(vgsales_final['Year'], errors='coerce')

# Round numeric values and convert to integers
vgsales_final['Year'] = vgsales_final['Year'].round().astype('Int64')

# Display the first few rows of the DataFrame
vgsales_final.head()
# Out:
#    Rank                      Name Platform  Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# ## Visualisation and Analysis

# %%
vgsales_final.describe() # displays relational statistics for all numerical columns in the dataframe
# Out:
#                Rank         Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16291.000000      16291.0  16291.000000  16291.000000  16291.000000
# mean    8290.190228  2006.405561      0.265647      0.147731      0.078833
# std     4792.654450     5.832412      0.822432      0.509303      0.311879
# min        1.000000       1980.0      0.000000      0.000000      0.000000
# 25%     4132.500000       2003.0      0.000000      0.000000      0.000000
# 50%     8292.000000       2007.0      0.080000      0.020000      0.000000
# 75%    12439.500000       2010.0      0.240000      0.110000      0.040000
# max    16600.000000       2020.0     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16291.000000  16291.000000
# mean       0.048426      0.540910
# std        0.190083      1.567345
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.480000
# ...

# %%
# showing the sum of sales for each region
total_sales = vgsales_final[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']].sum()
total_sales
# Out:
# NA_Sales        4327.65
# EU_Sales        2406.69
# JP_Sales        1284.27
# Other_Sales      788.91
# Global_Sales    8811.97
# dtype: float64

# %%
# creating a histogram of global sales using matplotlib
plt.figure(figsize=(8, 6))
plt.hist(vgsales_final['Global_Sales'], bins=30, color='skyblue', edgecolor='black')
plt.xlabel('Global Sales (millions)')
plt.ylabel('Frequency')
plt.title('Histogram of Global Sales')
plt.show()

# %%
# creating box plots for each regions sales
plt.figure(figsize=(10, 6))
sns.boxplot(data=vgsales_final[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']])
plt.ylabel('Sales (millions)')
plt.title('Box Plot of Sales by Region')
plt.show()

# %%
# creating a scatter plot of global sales across every year
plt.figure(figsize=(10, 6))
plt.scatter(vgsales_cleaned['Year'], vgsales_cleaned['Global_Sales'], alpha=0.5)
plt.xlabel('Year')
plt.ylabel('Global Sales (millions)')
plt.title('Scatter Plot of Global Sales vs. Year')
plt.show()

# %%
# Creating a bar plot of total sales by genre
plt.figure(figsize=(12, 6))
genre_sales = vgsales_final.groupby('Genre')['Global_Sales'].sum().sort_values(ascending=False)
sns.barplot(x=genre_sales.index, y=genre_sales.values, hue=genre_sales.index, palette='viridis', legend=False)
plt.xticks(rotation=45)
plt.xlabel('Genre')
plt.ylabel('Total Global Sales (millions)')
plt.title('Bar Plot of Total Sales by Genre')
plt.show()

# %%
# creating a pie chart showing the market share of each platform
plt.figure(figsize=(10, 8))
platform_sales = vgsales_final.groupby('Platform')['Global_Sales'].sum().sort_values(ascending=True)
plt.pie(platform_sales, labels=platform_sales.index, autopct='%1.0f%%',startangle=90)
plt.axis('equal')
plt.title('Pie Chart of Market Share by Platform')
plt.show()

# %%
# Get top publishers
top_publishers = vgsales_final['Publisher'].value_counts().head(5).index

# Plot time series chart for top publishers' sales over time
plt.figure(figsize=(12, 6))
for publisher in top_publishers:
    sales_by_publisher = vgsales_final[vgsales_cleaned['Publisher'] == publisher]
    sales_over_time = sales_by_publisher.groupby('Year')['Global_Sales'].sum()
    plt.plot(sales_over_time.index, sales_over_time, label=publisher)

plt.xlabel('Year')
plt.ylabel('Global Sales (millions)')
plt.title('Time Series Plot of Top Publishers\' Sales Over Time')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Conclusions

# %% [markdown]
# ## Descriptive analysis
# * Sales figures show North-America has the highest number of sales followed by Europe, Japan and other regions
# * The histogram shows a very heavy positively skewed distribution, where most global video game sales lie on
# the lower end and only hyper successful games make it past the 20 million sales mark
# * A standard deviation of 1.57 for global sales suggests a very spread out field of data compared to the mean
# sales figure, suggesting some video games perform very well, while others perform relatively poorly
# * The box plots figures show the data is heavily skewed and there is a significant number of outliers that is
#   affecting the plots appearance
# * The bar plot of total sales by genre show the top 3 category of games that have the highest number of sales
#   are action, sports and shooter
# * The pie chart shows the top 4 game platforms are PS2, XBOX 360, PS3, and Wii
# * The time series of top 5 publisher sales over time suggest a gradual increase in sales starting from the 1980's and
#   following that trend into the 2000s where gaming was at the height of its popularity culminating in the highest sales
#   around the 2000s, followed by a gradual decrease thereafter
# ## Key Takeaways
# * Publishers should look to prioritising making games for the North American and European markets over other regions due
#   to the variation in sales
# * Publishers can look at expanding their business in other regions by creating targeted advertisements campaigns
#   for new games
# * The global sales distribution indicates that only a select few games achieve widespread popularity, surpassing the 20
#   million sales mark. Therefore, it's crucial to consider budget constraints while setting expectations
# * To optimise sales publishers should choose to create new games in the following genres: Action, Sports, and Shooter
# * The market share being the highest with old gen consoles such as PS2, XBOX 360, and PS3 show there is huge popularity
#   within that community of customers. Therefore when creating new games for newer generation consoles, publishers can look to
#   game franchises that were popular in the older gen consoles and take inspiration from them or create new iterations of those games
